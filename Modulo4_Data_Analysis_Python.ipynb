# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-a00351269/blob/Modulo4_Data_Analysis_Python/Modulo4_Data_Analysis_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modulo 4 Curso: Data Analysis with Python IBM por
# <left>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Module%201/images/IDSNlogo.png" width="128" alt="cognitiveclass.ai logo"  />
# </center>
#
# ###Genaro Ramos Higuera
#
# ###Matricula A00351269
#
# ### Progreso del Modulo 4 Concluido Exitosamente
# ### Evidencias
#
# ![modulo4_progress.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# ##1. Regresion Lineal y Regresion Lineal Multiple:
#
# Regresion Lineal
#
# Regresion Lineal Simple: en donde trataremos de entender la relacion entre 2 variables.
#
# El predictor/variable independiente (X)
# Es el responsable de la variable dependiente (lo que deseamos predecir(Y)
#
# El resultado de la Regresion Lineal es una funcion lineal que predice el resultado de la variable dependiente Y como una funcion de la variable predictora (independiente) X .
#
# Y
# :
# R
# e
# s
# p
# u
# e
# s
# t
# a
#
# V
# a
# r
# i
# a
# b
# l
# e
# X
# :
# P
# r
# e
# d
# i
# c
# t
# o
# r
#
# V
# a
# r
# i
# a
# b
# l
# e
# s
# Lineal Funcion
# Y
# h
# a
# t
# =
# a
# +
# b
# X
#
# a es la intercepcion de la linea de regresion , en otras palabras: the value de Y cuando X es 0
# b es la inclinacion de la linea de regresion, en otras palabras: el valor en el cual Y cambia cuando X se incrementa en 1 unidad.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Cargamos el modelo en lm

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# Hacemos dos variables X y Y y veamos su relacion con el modelo

# %%
X = df[['highway-mpg']]
Y = df['price']

# %% [markdown]
# Entrenamos al modelo

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %% [markdown]
# What is the value of the intercept (a)?

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %% [markdown]
# What is the value of the slope (b)?

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# Cual es el modelo final obtenido?
#
# Y
# h
# a
# t
# =
# a
# +
# b
# X
#
# Queda asi:
#
# Price = 38423.31 - 821.73 x highway-mpg

# %% [markdown]
# QUESTION: Create a linear regression object called "lm1".?

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# QUESTION: Train the model using "engine-size" as the independent variable and "price" as the dependent variable?

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %% [markdown]
# Find the slope and intercept of the model.?

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# What is the equation of the predicted line? You can use x and yhat or "engine-size" or "price".?

# %%
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %% [markdown]
# ##Regresion Lineal Multiple:
#
# Que pasaria si deseamos predecir el precio (price) de un automovil con las de una variable?
#
# Aqui es donde una variable dependiente Y , va a ser predecida por multiples variables independientes X.
#
# $$
# Y: Respuesta/Salida \ Variable\\\\\\\\\\
# X\_1 :Predictor\ Variable \ 1\\\\
# X\_2: Predictor\ Variable \ 2\\\\
# X\_3: Predictor\ Variable \ 3\\\\
# X\_4: Predictor\ Variable \ 4\\\\
# $$
#
#
# $$
# a: interceptor\\\\\\\\\\
# b\_1 :coeficientes \ de\ Variable \ 1\\\\
# b\_2: coeficientes \ de\ Variable \ 2\\\\
# b\_3: coeficientes \ de\ Variable \ 3\\\\
# b\_4: coeficientes \ de\ Variable \ 4\\\\
# $$
#
# La ecuacion está dada por:
# $$
# Yhat = a + b\_1 X\_1 + b\_2 X\_2 + b\_3 X\_3 + b\_4 X\_4
# $$
#
# Vimos que teniamos buenos predictores en la seccion anterior:
#
# Horsepower
# Curb-weight
# Engine-size
# Highway-mpg

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# Una vez entrenado veamos el intercept_

# %%
lm.intercept_
# Out:
# -15806.62462632922

# %% [markdown]
# Ahora los corficientes

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# La ecuacion queda asi:
#
# Price = -15678.742628061467 + 52.65851272 x horsepower + 4.69878948 x curb-weight + 81.95906216 x engine-size + 33.58258185 x highway-mpg

# %% [markdown]
# QUESTIONS:
#
# Create and train a Multiple Linear Regression model "lm2" where the response variable is "price", and the predictor variable is "normalized-losses" and "highway-mpg".?

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# Encontramos el coeficiente del modelo.

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# ##2. Evaluacion del modelo utilizando Visualizacion

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Regression Plot

# %% [markdown]
# Veamos la grafica de regresion entre estas dos variables.

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48173.24967758195)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# QUESTIONS:
#
# Given the regression plots above, is "peak-rpm" or "highway-mpg" more strongly correlated with "price"? Use the method ".corr()" to verify your answer.

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# #Residual Plot
#
# Una buena manera de visualizar la varianza de los datos es usar residual plot.
#
# Que es un residual?
#
# Es la diferencia entre el valor observado  (y) y el valor predecido(Yhat) que es llamado residual (e). Cuando vemos un regression plot, el residual es la distancia del punto de datos a la linea de ajuste de regresion.
#
# ###Que es el residual plot?
#
# Es una grafica que muestra los residuoes en el eje vertical Y y la variable independiente X, en el eje X.
#
# **Que detectar?**
#
# - Si los puntos en el grafica estar aleatoriamente disperson alrededor del eje x, entonces el modelo linea es apropiado para los datos.
#
# **Aleatoriamente distribuidos, significa que la media de la varianza es constante**

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %% [markdown]
# ##Como visualizar una regresion lineal multiple

# %%
Y_hat = lm.predict(Z)
Y_hat
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097, 10722.32509097, 17804.80307397,
#        18063.72662867, 19320.78745066, 26968.56492801, 27674.72007721,
#        28191.0677239 ,   650.62317688,  5648.50489642,  5813.27443123,
#         5478.81383232,  5370.64136587,  8739.61952024,  5799.04215638,
#         5902.61157827,  5902.61157827,  9036.2046829 , 11863.43973759,
#        18767.70667001,  4808.3090102 ,  5693.32889063,  4006.47212651,
#         6118.73075572,  6194.05397163,  6448.26982534,  6514.17763926,
#         9478.65495235,  9728.16310506,  9798.77861998, 10118.90228761,
#        11178.86719942, 10423.81935057,  9463.46710755, 12626.61544369,
#        34470.03895495, 34470.03895495, 43996.52260522,  5265.67702191,
#         5565.15645357,  5588.69495854,  5777.00299832,  5800.5415033 ,
# ...

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Podemos ver que los valores pronosticados (AZUL) estan razonablemente cerca de los valores actuales (ROJO) ya que las dos distribuciones casi se enciman una sobre otra. SIn embargo hay espacio para mejorar.

# %% [markdown]
# ##3. Regresion Polinomial y Pipelines
#
# Es un caso de regresion lineal multiple donde las relaciones ya no son lineales sino de mas grande orden de las variables predictoras
#
# Hay diferentes grados:
#
# <center><b>Cuadratico- 2nd Orden</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2
# $$
#
# <center><b>Cubico - 3rd Orden</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2 +b_3 X^3\\\\\\\\\\
# $$
#
# <center><b>Alto-Orden</b>:</center>
# $$
# Y = a + b_1 X +b_2 X^2 +b_3 X^3 ....\\\\
# $$

# %% [markdown]
# Definimos una funcion para graficar

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# ##Question #4:
# ##Create 11 order polynomial model with the variables x and y from above.

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %% [markdown]
# ### Ahora veamos este polinomio:
#
# $$
# Yhat = a + b\_1 X\_1 +b\_2 X\_2 +b\_3 X\_1 X\_2+b\_4 X\_1^2+b\_5 X\_2^2
# $$

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %% [markdown]
# #Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Creamos el pipeline creando una lista de tuples que incluyan el nombre del modelo o estimador y su correspondiente constructor.

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %% [markdown]
# asignamos a Input como argumento al pipeline constructor:

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# COnvertimos los datos type Z a type float para evitar warnings al usar el  StandardScaler:
#
#
# Normalizamos los datos y realizamos una transformacion y entrenamos al modelo simultaneamente.

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# Normalizamos los datos y realizamos una transformacion y entrenamos al modelo simultaneamente.

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %%
ypipe.shape
# Out:
# (201,)

# %% [markdown]
# ##Question #5:
# ###Create a pipeline that standardizes the data, then produce a prediction using a linear regression model using the features Z and target y.

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# #4. Medidas para evaluacion In-Sample
#
# **R^2 / R-squared**
#
# **Mean Squared Error (MSE)**
#
#
# **Mean Squared Error (MSE)**

# %% [markdown]
# ##Modelo 1: Regresion lineal Simple

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %% [markdown]
# ##Modelo 2: Regresion Lineal Multiple

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %% [markdown]
# Modelo 3: Polynomial Fit

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %% [markdown]
# p(x) es el polinomio que definimos con np.poly

# %% [markdown]
# y x = df['highway-mpg']

# %%
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# #5. Prediction and Decision Making

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:10]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655, 33492.90558823, 32671.1722099 , 31849.43883158,
#        31027.70545326, 30205.97207494])

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# Toma de decisiones: Determinando un buen model Fit
#
# ahora que hemos visualizado diferentes modelos y generado los valores de  R-squared y MSE de los fits, como sabemos si es un buen modelo?
#
#
# **Que es un buen valor de R-squared ?**
#
# Cuando se comparan los modelos , el modelo con el **MAS GRANDE valor de R-squared** es el mejor para el fit de la data.
#
# ** que es un buen valor de MSE?**
# Cuando se comparan los modelos el **valor menor de de MSE** es el que mejor para el fit de la daTA.
#
# VEAMOS LOS VALORES:
#
# 1) Simple Linear Regression: Using Highway-mpg as a Predictor Variable of Price.
#
# R-squared: 0.49659118843391759
#
# MSE: 3.16 x10^7
#
#
# 2) Multiple Linear Regression:
#
# Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
#
# R-squared: 0.80896354913783497
#
# MSE: 1.2 x10^7
#
#
# 3) Polynomial Fit: Using Highway-mpg as a Predictor Variable of Price.
#
# R-squared: 0.6741946663906514
#
# MSE: 2.05 x 10^7
#
#
#
#
#
# Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)
# Usually, the more variables you have, the better your model is at predicting, but this is not always true.
#
#
# Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, you should always check the MSE and R^2.
#
#
# In order to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
#
# MSE: The MSE of SLR is 3.16x10^7 while MLR has an MSE of 1.2 x10^7.
#
# The MSE of MLR is much smaller.
#
# R-squared: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR.
#
# The R-squared for the SLR (0.497) is very small compared to the R-squared for the MLR (0.809).
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.
#
#
# **Simple Linear Model (SLR) vs. Polynomial Fit**
#
# MSE: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.
#
# R-squared: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.
# Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.
#
# Multiple Linear Regression (MLR) vs. Polynomial Fit
#
# MSE: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.
# R-squared: The R-squared for the MLR is also much larger than for the Polynomial Fit.
